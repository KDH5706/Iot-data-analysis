# %% [markdown]
# ### 스타벅스, 이디야 매장 위치비교
#
# - 맥도날드는 위치선정시, 각 연령별로 유동인구수 체크 매장 입지 선정
# - 롯데리아는 맥도날드가 선정한 위치 근처에 매장을 개설
# - 스타벅스도 거의 동일, 이디야도 스타벅스 근처에 입점한다고 함

# %% [markdown]
# #### 데이터셋 생성
# - 공공데이터 포털 내 소상공인진흥공단 상가, 상권 분석 정보 활용
# 	- https://www.data.go.kr/data/15083033/fileData.do
# 	- c\csv 압축파일 다운로드, 서울 정보 압축해제

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# ### 플롯에서 한글 깨짐 방지

# %%
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

sns.set_theme(style='darkgrid', palette='deep', font='NanumGothic')

# %% [markdown]
# ### 서울 상권정보 CSV 로드

# %%
df = pd.read_csv('./data/소상공인시장진흥공단_상가(상권)정보_서울_202409.csv', encoding='utf-8')
df.shape
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16412\147041081.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/소상공인시장진흥공단_상가(상권)정보_서울_202409.csv', encoding='utf-8')
# (466022, 39)

# %%
df.head()
# Out:
#                  상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0093845     이상한스냅  NaN        M1    과학·기술      M113
# 1  MA010120220805430767       토끼정  NaN        I2       음식      I201
# 2  MA010120220805430797       가배차  NaN        I2       음식      I201
# 3  MA010120220805430812  비에이치씨항동점  NaN        I2       음식      I210
# 4  MA010120220805430834   무지개삼성약국  NaN        G2       소매      G215
#
#     상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0      사진 촬영    M11301    사진촬영업   M73303  ...  1147010300100090004000001
# 1         한식    I20101   백반/한정식   I56111  ...  1150010500107740012000001
# 2         한식    I20101   백반/한정식   I56111  ...  1171010400101430002012823
# 3      기타 간이    I21006       치킨   I56193  ...  1153011200101000005000001
# 4  의약·화장품 소매    G21501       약국   G47811  ...  1168011400106840005002734
#
#                건물명              도로명주소   구우편번호 신우편번호  동정보  층정보  호정보  \
# 0             백송주택  서울특별시 양천구 월정로 283  158822  7902  NaN  NaN  NaN
# 1            마커스빌딩  서울특별시 강서구 마곡동로 55  157805  7802  NaN    2  NaN
# 2           사이언스빌딩  서울특별시 송파구 가락로 209  138852  5663  NaN    1  NaN
# 3  항동중흥에스클래스베르데카운티  서울특별시 구로구 연동로 233  152140  8362  NaN    1  NaN
# 4             대훈빌딩   서울특별시 강남구 일원로 45  135516  6343  NaN  NaN  NaN
#
#            경도         위도
# 0  126.828832  37.542117
# 1  126.833022  37.560053
# 2  127.116136  37.507170
# 3  126.820686  37.481640
# 4  127.081499  37.489893
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466022 entries, 0 to 466021
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     466022 non-null  object
#  1   상호명        466022 non-null  object
#  2   지점명        11406 non-null   object
#  3   상권업종대분류코드  466022 non-null  object
#  4   상권업종대분류명   466022 non-null  object
#  5   상권업종중분류코드  466022 non-null  object
#  6   상권업종중분류명   466022 non-null  object
#  7   상권업종소분류코드  466022 non-null  object
#  8   상권업종소분류명   466022 non-null  object
#  9   표준산업분류코드   465931 non-null  object
#  10  표준산업분류명    465931 non-null  object
#  11  시도코드       466022 non-null  int64
#  12  시도명        466022 non-null  object
#  13  시군구코드      466022 non-null  int64
#  14  시군구명       466022 non-null  object
#  15  행정동코드      466022 non-null  int64
#  16  행정동명       466022 non-null  object
#  17  법정동코드      466022 non-null  int64
#  18  법정동명       466022 non-null  object
#  19  지번코드       466022 non-null  int64
#  20  대지구분코드     466022 non-null  int64
#  21  대지구분명      466022 non-null  object
#  22  지번본번지      466022 non-null  int64
#  23  지번부번지      389662 non-null  float64
#  24  지번주소       466022 non-null  object
#  25  도로명코드      465993 non-null  float64
#  26  도로명        466022 non-null  object
#  27  건물본번지      465992 non-null  float64
#  28  건물부번지      61598 non-null   float64
#  29  건물관리번호     465993 non-null  object
#  30  건물명        221552 non-null  object
#  31  도로명주소      466022 non-null  object
#  32  구우편번호      466022 non-null  int64
#  33  신우편번호      466022 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        322768 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         466022 non-null  float64
#  38  위도         466022 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 138.7+ MB

# %%
## 결측치 확인
df.isna().sum().plot.bar(figsize=(20,5), color='crimson')
# Out:
# <Axes: >

# %% [markdown]
# ##### 필요 컬럼만 추출(상호명, 주소, 행정동명, 법정동명, 도로명주소, 위도, 경도)

# %%
columns = ['상호명', '상권업종소분류명', '시도명', '시군구명', '지번주소', '도로명주소', '경도', '위도']

df_business = df[columns].copy()
df_business
# Out:
#                상호명   상권업종소분류명    시도명  시군구명                   지번주소  \
# 0            이상한스냅      사진촬영업  서울특별시   양천구      서울특별시 양천구 신월동 9-4
# 1              토끼정     백반/한정식  서울특별시   강서구   서울특별시 강서구 마곡동 774-12
# 2              가배차     백반/한정식  서울특별시   송파구    서울특별시 송파구 송파동 143-2
# 3         비에이치씨항동점         치킨  서울특별시   구로구     서울특별시 구로구 항동 100-5
# 4          무지개삼성약국         약국  서울특별시   강남구    서울특별시 강남구 일원동 684-5
# ...            ...        ...    ...   ...                    ...
# 466017        이문족발      족발/보쌈  서울특별시  동대문구  서울특별시 동대문구 이문동 305-79
# 466018        농가통닭         치킨  서울특별시   광진구    서울특별시 광진구 중곡동 78-11
# 466019    동아철거인테리어  인테리어 디자인업  서울특별시   종로구   서울특별시 종로구 명륜2가 208-5
# 466020  유메오뎅종로익선동점    일식 회/초밥  서울특별시   종로구     서울특별시 종로구 돈의동 44-1
# 466021          설빙         카페  서울특별시   관악구   서울특별시 관악구 신림동 1640-1
#
#                         도로명주소          경도         위도
# 0           서울특별시 양천구 월정로 283  126.828832  37.542117
# 1           서울특별시 강서구 마곡동로 55  126.833022  37.560053
# 2           서울특별시 송파구 가락로 209  127.116136  37.507170
# 3           서울특별시 구로구 연동로 233  126.820686  37.481640
# 4            서울특별시 강남구 일원로 45  127.081499  37.489893
# ...                       ...         ...        ...
# 466017  서울특별시 동대문구 휘경로2길 5-12  127.061632  37.595376
# 466018       서울특별시 광진구 영화사로 5  127.088365  37.558526
# 466019     서울특별시 종로구 성균관로 6-5  126.998555  37.583775
# 466020   서울특별시 종로구 돈화문로11길 18  126.990349  37.572677
# 466021   서울특별시 관악구 남부순환로 1598  126.928318  37.483755
#
# [466022 rows x 8 columns]

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466022 entries, 0 to 466021
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       466022 non-null  object
#  1   상권업종소분류명  466022 non-null  object
#  2   시도명       466022 non-null  object
#  3   시군구명      466022 non-null  object
#  4   지번주소      466022 non-null  object
#  5   도로명주소     466022 non-null  object
#  6   경도        466022 non-null  float64
#  7   위도        466022 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 28.4+ MB

# %%
df_business.head()
# Out:
#         상호명 상권업종소분류명    시도명 시군구명                  지번주소              도로명주소  \
# 0     이상한스냅    사진촬영업  서울특별시  양천구     서울특별시 양천구 신월동 9-4  서울특별시 양천구 월정로 283
# 1       토끼정   백반/한정식  서울특별시  강서구  서울특별시 강서구 마곡동 774-12  서울특별시 강서구 마곡동로 55
# 2       가배차   백반/한정식  서울특별시  송파구   서울특별시 송파구 송파동 143-2  서울특별시 송파구 가락로 209
# 3  비에이치씨항동점       치킨  서울특별시  구로구    서울특별시 구로구 항동 100-5  서울특별시 구로구 연동로 233
# 4   무지개삼성약국       약국  서울특별시  강남구   서울특별시 강남구 일원동 684-5   서울특별시 강남구 일원로 45
#
#            경도         위도
# 0  126.828832  37.542117
# 1  126.833022  37.560053
# 2  127.116136  37.507170
# 3  126.820686  37.481640
# 4  127.081499  37.489893

# %%
df_business[df_business['시도명'] == '서울특별시'].count()
# Out:
# 상호명         466022
# 상권업종소분류명    466022
# 시도명         466022
# 시군구명        466022
# 지번주소        466022
# 도로명주소       466022
# 경도          466022
# 위도          466022
# dtype: int64

# %%
df_business[df_business['상권업종소분류명'] == '카페'].count()
# Out:
# 상호명         20454
# 상권업종소분류명    20454
# 시도명         20454
# 시군구명        20454
# 지번주소        20454
# 도로명주소       20454
# 경도          20454
# 위도          20454
# dtype: int64

# %%
#### 상권업종소분류명 카페로 필터링
df_cafe = df_business[df_business['상권업종소분류명'] == '카페'].copy()
df_cafe
# Out:
#                상호명 상권업종소분류명    시도명  시군구명                    지번주소  \
# 7              카페숲       카페  서울특별시   금천구    서울특별시 금천구 시흥동 929-10
# 51         매머드커피외대       카페  서울특별시  동대문구  서울특별시 동대문구 이문동 264-223
# 53            포르마레       카페  서울특별시   강동구     서울특별시 강동구 성내동 534-7
# 111     더웨이유통할리스커피       카페  서울특별시    중구     서울특별시 중구 신당동 368-66
# 116          카페브릿지       카페  서울특별시  영등포구      서울특별시 영등포구 여의도동 22
# ...            ...      ...    ...   ...                     ...
# 465929         두들렌       카페  서울특별시   강서구     서울특별시 강서구 등촌동 664-2
# 465938          키에       카페  서울특별시    중구        서울특별시 중구 황학동 570
# 465998          공차       카페  서울특별시   강북구      서울특별시 강북구 미아동 1364
# 465999        신길어름       카페  서울특별시   금천구     서울특별시 금천구 가산동 60-15
# 466021          설빙       카페  서울특별시   관악구    서울특별시 관악구 신림동 1640-1
#
#                         도로명주소          경도         위도
# 7       서울특별시 금천구 시흥대로40길 129  126.909939  37.446689
# 51       서울특별시 동대문구 천장산로7길 16  127.056962  37.598493
# 53         서울특별시 강동구 성내로9길 35  127.125070  37.530474
# 111          서울특별시 중구 다산로 114  127.010407  37.553952
# 116       서울특별시 영등포구 여의대로 108  126.929094  37.525184
# ...                       ...         ...        ...
# 465929     서울특별시 강서구 공항대로 337  126.845151  37.558118
# 465938     서울특별시 중구 퇴계로87길 37  127.020953  37.567159
# 465998       서울특별시 강북구 도봉로 52  127.030514  37.613695
# 465999      서울특별시 금천구 벚꽃로 286  126.884101  37.480382
# 466021   서울특별시 관악구 남부순환로 1598  126.928318  37.483755
#
# [20454 rows x 8 columns]

# %% [markdown]
# ### 카페 데이터프레임에서 이디야, 스타벅스 확인

# %%
# 카페데이터 2만여개중 이디야는 496개 존재
df_cafe['상호명'].str.contains('이디야|이디아|ediya').sum()
# Out:
# 496

# %%
# 스타벅스는 0개
df_cafe['상호명'].str.contains('스타벅스|starbucks').sum()

# %% [markdown]
# - 2022년까지는 소상공인 데이터에 스타벅스가 포함되어 있었음
# - 현재는 스타벅스 데이터가 존재하지 않음
# - 스타벅스 데이터는 스타벅스 사이트에서 seleninum으로 추출한 데이터를 활용

# %% [markdown]
# ### 지난주 Selenium으로 추출한 스타벅스 매장정보

# %%
df_starbuck = pd.read_csv('./data/스타벅스_서울매장정보.csv', encoding='utf-8')
df_starbuck
# Out:
#          매장명         위도          경도    구  \
# 0    역삼아레나빌딩  37.501087  127.043069  강남구
# 1     논현역사거리  37.510178  127.022223  강남구
# 2    신사역성일빌딩  37.513931  127.020606  강남구
# 3     국기원사거리  37.499517  127.031495  강남구
# 4     대치재경빌딩  37.494668  127.062583  강남구
# ..       ...        ...         ...  ...
# 622      상봉역  37.596890  127.086470  중랑구
# 623       묵동  37.615368  127.076633  중랑구
# 624      망우동  37.599508  127.097539  중랑구
# 625      양원역  37.606654  127.106360  중랑구
# 626      중화역  37.601709  127.078411  중랑구
#
#                                         주소       전화번호     매장타입
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232  general
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232  general
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232  general
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  general
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  general
# ..                                     ...        ...      ...
# 622                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  general
# 623  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  general
# 624                서울특별시 중랑구 망우로 407 (망우동)  1522-3232  general
# 625              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  general
# 626                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  general
#
# [627 rows x 7 columns]

# %%
df_ediya = df_cafe[df_cafe['상호명'].str.contains('이디야|이디아|ediya')].copy()
df_ediya
# Out:
#                        상호명 상권업종소분류명    시도명  시군구명                  지번주소  \
# 175               이디야까치산로점       카페  서울특별시   강서구    서울특별시 강서구 화곡동 1167
# 2708            이디야커피하월곡동점       카페  서울특별시   성북구  서울특별시 성북구 하월곡동 67-37
# 2805    앙크인베스트먼트이디야커피국회대로점       카페  서울특별시  영등포구  서울특별시 영등포구 여의도동 14-3
# 2816               이디야화곡본동       카페  서울특별시   강서구   서울특별시 강서구 화곡동 98-83
# 4981              이디야망리단길점       카페  서울특별시   마포구   서울특별시 마포구 망원동 399-5
# ...                    ...      ...    ...   ...                   ...
# 456925             이디야커피가락       카페  서울특별시   송파구      서울특별시 송파구 가락동 48
# 459225               이디야용산       카페  서울특별시   용산구    서울특별시 용산구 한강로3가 60
# 461959          이디야등촌3동성당점       카페  서울특별시   강서구   서울특별시 강서구 등촌동 667-7
# 463911             이디야커피중계       카페  서울특별시   노원구   서울특별시 노원구 중계동 84-19
# 464427            이디야천호1동점       카페  서울특별시   강동구  서울특별시 강동구 천호동 395-78
#
#                        도로명주소          경도         위도
# 175       서울특별시 강서구 까치산로 182  126.853872  37.553302
# 2708       서울특별시 성북구 오패산로 16  127.037474  37.603643
# 2805    서울특별시 영등포구 국회대로72길 4  126.919901  37.530326
# 2816     서울특별시 강서구 까치산로4길 11  126.844242  37.542215
# 4981      서울특별시 마포구 포은로 81-1  126.905250  37.554303
# ...                      ...         ...        ...
# 456925      서울특별시 송파구 송이로 87  127.120775  37.498338
# 459225   서울특별시 용산구 한강대로 52-1  126.964637  37.525419
# 461959  서울특별시 강서구 강서로56길 110  126.844857  37.558863
# 463911   서울특별시 노원구 중계로14바길 2  127.082558  37.649874
# 464427  서울특별시 강동구 구천면로34길 43  127.133575  37.542539
#
# [496 rows x 8 columns]

# %%
## copy했던 인덱스를 다시 초기화
df_ediya.reset_index(inplace=True)
df_ediya
# Out:
#       index                 상호명 상권업종소분류명    시도명  시군구명                  지번주소  \
# 0       175            이디야까치산로점       카페  서울특별시   강서구    서울특별시 강서구 화곡동 1167
# 1      2708          이디야커피하월곡동점       카페  서울특별시   성북구  서울특별시 성북구 하월곡동 67-37
# 2      2805  앙크인베스트먼트이디야커피국회대로점       카페  서울특별시  영등포구  서울특별시 영등포구 여의도동 14-3
# 3      2816             이디야화곡본동       카페  서울특별시   강서구   서울특별시 강서구 화곡동 98-83
# 4      4981            이디야망리단길점       카페  서울특별시   마포구   서울특별시 마포구 망원동 399-5
# ..      ...                 ...      ...    ...   ...                   ...
# 491  456925             이디야커피가락       카페  서울특별시   송파구      서울특별시 송파구 가락동 48
# 492  459225               이디야용산       카페  서울특별시   용산구    서울특별시 용산구 한강로3가 60
# 493  461959          이디야등촌3동성당점       카페  서울특별시   강서구   서울특별시 강서구 등촌동 667-7
# 494  463911             이디야커피중계       카페  서울특별시   노원구   서울특별시 노원구 중계동 84-19
# 495  464427            이디야천호1동점       카페  서울특별시   강동구  서울특별시 강동구 천호동 395-78
#
#                     도로명주소          경도         위도
# 0      서울특별시 강서구 까치산로 182  126.853872  37.553302
# 1       서울특별시 성북구 오패산로 16  127.037474  37.603643
# 2    서울특별시 영등포구 국회대로72길 4  126.919901  37.530326
# 3     서울특별시 강서구 까치산로4길 11  126.844242  37.542215
# 4      서울특별시 마포구 포은로 81-1  126.905250  37.554303
# ..                    ...         ...        ...
# 491      서울특별시 송파구 송이로 87  127.120775  37.498338
# 492   서울특별시 용산구 한강대로 52-1  126.964637  37.525419
# 493  서울특별시 강서구 강서로56길 110  126.844857  37.558863
# 494   서울특별시 노원구 중계로14바길 2  127.082558  37.649874
# 495  서울특별시 강동구 구천면로34길 43  127.133575  37.542539
#
# [496 rows x 9 columns]

# %% [markdown]
# ##### 스타벅스 매장명 앞에 '스타벅스' 문자열 추가

# %%
df_starbuck['매장명'] = '스타벅스' + df_starbuck['매장명']
df_starbuck.tail()
# Out:
#              매장명         위도          경도    구  \
# 622  스타벅스스타벅스상봉역  37.596890  127.086470  중랑구
# 623   스타벅스스타벅스묵동  37.615368  127.076633  중랑구
# 624  스타벅스스타벅스망우동  37.599508  127.097539  중랑구
# 625  스타벅스스타벅스양원역  37.606654  127.106360  중랑구
# 626  스타벅스스타벅스중화역  37.601709  127.078411  중랑구
#
#                                         주소       전화번호     매장타입
# 622                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  general
# 623  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  general
# 624                서울특별시 중랑구 망우로 407 (망우동)  1522-3232  general
# 625              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  general
# 626                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  general

# %% [markdown]
# ##### 각 데이터프레임에 '프랜드명'이라는 신규 컬럼 추가

# %%
df_ediya['브랜드명'] = '이디야'
df_starbuck['브랜드명'] = '스타벅스'

# %%
df_ediya.tail()
# Out:
#       index         상호명 상권업종소분류명    시도명 시군구명                  지번주소  \
# 491  456925     이디야커피가락       카페  서울특별시  송파구      서울특별시 송파구 가락동 48
# 492  459225       이디야용산       카페  서울특별시  용산구    서울특별시 용산구 한강로3가 60
# 493  461959  이디야등촌3동성당점       카페  서울특별시  강서구   서울특별시 강서구 등촌동 667-7
# 494  463911     이디야커피중계       카페  서울특별시  노원구   서울특별시 노원구 중계동 84-19
# 495  464427    이디야천호1동점       카페  서울특별시  강동구  서울특별시 강동구 천호동 395-78
#
#                     도로명주소          경도         위도 브랜드명
# 491      서울특별시 송파구 송이로 87  127.120775  37.498338  이디야
# 492   서울특별시 용산구 한강대로 52-1  126.964637  37.525419  이디야
# 493  서울특별시 강서구 강서로56길 110  126.844857  37.558863  이디야
# 494   서울특별시 노원구 중계로14바길 2  127.082558  37.649874  이디야
# 495  서울특별시 강동구 구천면로34길 43  127.133575  37.542539  이디야

# %%
df_starbuck.tail()
# Out:
#              매장명         위도          경도    구  \
# 622  스타벅스스타벅스상봉역  37.596890  127.086470  중랑구
# 623   스타벅스스타벅스묵동  37.615368  127.076633  중랑구
# 624  스타벅스스타벅스망우동  37.599508  127.097539  중랑구
# 625  스타벅스스타벅스양원역  37.606654  127.106360  중랑구
# 626  스타벅스스타벅스중화역  37.601709  127.078411  중랑구
#
#                                         주소       전화번호     매장타입  브랜드명
# 622                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  general  스타벅스
# 623  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  general  스타벅스
# 624                서울특별시 중랑구 망우로 407 (망우동)  1522-3232  general  스타벅스
# 625              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  general  스타벅스
# 626                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  general  스타벅스

# %% [markdown]
# #### 두 DF에서 공통된 컬럼만 추출
# - 매장명(상호명), 구명, 도로명주소(주소), 위도, 경도, 브랜드명

# %%
df_ediya = df_ediya[['브랜드명', '상호명', '시군구명', '도로명주소', '위도', '경도']]
df_ediya.head()
# Out:
#   브랜드명                 상호명  시군구명                 도로명주소         위도          경도
# 0  이디야            이디야까치산로점   강서구    서울특별시 강서구 까치산로 182  37.553302  126.853872
# 1  이디야          이디야커피하월곡동점   성북구     서울특별시 성북구 오패산로 16  37.603643  127.037474
# 2  이디야  앙크인베스트먼트이디야커피국회대로점  영등포구  서울특별시 영등포구 국회대로72길 4  37.530326  126.919901
# 3  이디야             이디야화곡본동   강서구   서울특별시 강서구 까치산로4길 11  37.542215  126.844242
# 4  이디야            이디야망리단길점   마포구    서울특별시 마포구 포은로 81-1  37.554303  126.905250

# %%
df_starbuck = df_starbuck[['브랜드명', '매장명', '구', '주소', '위도', '경도']]
df_starbuck.head()
# Out:
#    브랜드명              매장명    구                          주소         위도  \
# 0  스타벅스  스타벅스스타벅스역삼아레나빌딩  강남구     서울특별시 강남구 언주로 425 (역삼동)  37.501087
# 1  스타벅스   스타벅스스타벅스논현역사거리  강남구    서울특별시 강남구 강남대로 538 (논현동)  37.510178
# 2  스타벅스  스타벅스스타벅스신사역성일빌딩  강남구    서울특별시 강남구 강남대로 584 (논현동)  37.513931
# 3  스타벅스   스타벅스스타벅스국기원사거리  강남구    서울특별시 강남구 테헤란로 125 (역삼동)  37.499517
# 4  스타벅스   스타벅스스타벅스대치재경빌딩  강남구  서울특별시 강남구 남부순환로 2947 (대치동)  37.494668
#
#            경도
# 0  127.043069
# 1  127.022223
# 2  127.020606
# 3  127.031495
# 4  127.062583

# %% [markdown]
# #### DF 합치기

# %%
# pd.merge() SQL에 Join 하고 동일, INNER JOIN, LEFT(RIGHT) OUTER JOIN
# pd.concat SQL UNION 하고 동일
# 컬럼명이 해당 컬럼명이 없는 레코드는 NaN으로 채워짐

# %%
df_starbuck.columns = ['브랜드명', '매장명', '구', '주소', '위도', '경도']
df_ediya.columns = ['브랜드명', '매장명', '구', '주소', '위도', '경도']

df_total = pd.concat([df_starbuck, df_ediya], ignore_index=True)
df_total.tail()
# Out:
#      브랜드명         매장명    구                    주소         위도          경도
# 1118  이디야     이디야커피가락  송파구      서울특별시 송파구 송이로 87  37.498338  127.120775
# 1119  이디야       이디야용산  용산구   서울특별시 용산구 한강대로 52-1  37.525419  126.964637
# 1120  이디야  이디야등촌3동성당점  강서구  서울특별시 강서구 강서로56길 110  37.558863  126.844857
# 1121  이디야     이디야커피중계  노원구   서울특별시 노원구 중계로14바길 2  37.649874  127.082558
# 1122  이디야    이디야천호1동점  강동구  서울특별시 강동구 구천면로34길 43  37.542539  127.133575

# %%
# 최종 데이터프레임 저장
df_total.to_csv('./data/서울_스타벅스_이디야_매장정보.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### 데이터 시각화
#
# #### 브랜드별 매장수

# %%
## 넘파이 ndarray 형태로 표시
df_total['브랜드명'].values # 속성
# Out:
# array(['스타벅스스타벅스역삼아레나빌딩', '스타벅스스타벅스논현역사거리', '스타벅스스타벅스신사역성일빌딩', ...,
#        '이디야등촌3동성당점', '이디야커피중계', '이디야천호1동점'], dtype=object)

# %%
df_total['브랜드명'].value_counts() # 함수
# Out:
# 브랜드명
# 스타벅스    627
# 이디야     496
# Name: count, dtype: int64

# %%
# matplotlib bar 차트나 seaborn.countplot를 사용해도 됨
_, ax = plt.subplots(figsize = (20,5))
sns.countplot(data=df_total, x='브랜드명', hue='브랜드명')

for p in ax.patches: # x축 값을 반복해서
	ax.text(p.get_x() + (p.get_width() / 2),
		 	p.get_y() + p.get_height() + 10,
			f'{p.get_height():.0f}',
			ha='center')

plt.title('브랜드별 매장수')
plt.ylabel('매장수')
plt.show() ## matplotlib 추가메시지를 표시하지 않음

# %%
# matplotlib bar 차트나 seaborn.countplot를 사용해도 됨
_, ax = plt.subplots(figsize = (20,5))
sns.countplot(data=df_total, x='구', hue='브랜드명')

for p in ax.patches: # x축 값을 반복해서
	if(p.get_height() == 0) : continue
	ax.text(p.get_x() + (p.get_width() / 2),
		 	p.get_y() + p.get_height() + 2,
			f'{p.get_height():.0f}',
			ha='center')
	
plt.title('구별 브랜드별 매장수')
plt.ylabel('매장수')
plt.show() ## matplotlib 추가메시지를 표시하지 않음

# %%
df_total.groupby(['구','브랜드명'])['매장명'].count()
# Out:
# 구     브랜드명
# 강남구   스타벅스    94
#       이디야     28
# 강동구   스타벅스    18
#       이디야     21
# 강북구   스타벅스     7
#       이디야     10
# 강서구   스타벅스    28
#       이디야     27
# 관악구   스타벅스    13
#       이디야     18
# 광진구   스타벅스    19
#       이디야     16
# 구로구   스타벅스    14
#       이디야     20
# 금천구   스타벅스    15
#       이디야     13
# 노원구   스타벅스    15
#       이디야     17
# 도봉구   스타벅스     7
#       이디야     15
# 동대문구  스타벅스    13
#       이디야     20
# 동작구   스타벅스    11
#       이디야     15
# 마포구   스타벅스    37
#       이디야     24
# 서대문구  스타벅스    21
#       이디야     14
# 서초구   스타벅스    50
#       이디야     23
# 성동구   스타벅스    15
#       이디야     15
# 성북구   스타벅스    16
#       이디야     23
# 송파구   스타벅스    37
#       이디야     26
# 양천구   스타벅스    17
#       이디야     16
# 영등포구  스타벅스    41
#       이디야     34
# 용산구   스타벅스    25
#       이디야     12
# 은평구   스타벅스    14
#       이디야     18
# 종로구   스타벅스    39
#       이디야     25
# 중구    스타벅스    52
#       이디야     23
# 중랑구   스타벅스     9
#       이디야     23
# Name: 매장명, dtype: int64

# %%
df_total['구'].str.contains('강남구').value_counts()
# Out:
# 구
# False    1001
# True      122
# Name: count, dtype: int64

# %%
# Scatterplot
df_total[['위도','경도']].plot.scatter(x='경도', y='위도')
plt.show()

# %%
sns.scatterplot(data = df_total, x= '경도', y='위도', hue='브랜드명')
plt.show()

# %% [markdown]
# ### 지도 시각화

# %%
map = folium.Map(location=[37.5566, 126.9884], zoom_start=12)

for i in df_total.index:
    cafe_lat = df_total.loc[i, '위도']
    cafe_lng = df_total.loc[i, '경도']
    title = f"{df_total.loc[i, '매장명']} / {df_total.loc[i, '주소']}"
    
    color = 'blue'
    
    if df_total.loc[i, '브랜드명'] != '스타벅스' : color = 'orange'
    
    folium.CircleMarker(location=[cafe_lat, cafe_lng], radius=3, color = color, tooltip=title).add_to(map)
    
map

# %%
import json

geojson_data = './data/seoul_geo_simple.json'
seoul_geo = json.load(open(geojson_data, encoding='utf-8'))

gu_map = folium.Map(location=[37.5566, 126.9884], zoom_start=11)


folium.GeoJson(seoul_geo, name='서울특별시 행정구').add_to(gu_map)

for i in df_total.index:
    cafe_lat = df_total.loc[i, '위도']
    cafe_lng = df_total.loc[i, '경도']
    title = f"{df_total.loc[i, '매장명']} / {df_total.loc[i, '주소']}"
    
    color = 'blue'
    
    if df_total.loc[i, '브랜드명'] != '스타벅스' : color = 'orange'
    
    folium.CircleMarker(location=[cafe_lat, cafe_lng], radius=3, color = color, tooltip=title).add_to(gu_map)


gu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b858da06f3dd8a804ba21b8686788fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b858da06f3dd8a804ba21b8686788fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b858da06f3dd8a804ba21b8686788fb = L.map(
#                 &quot;map_7b858da06f3dd8a804ba21b8686788fb&quot;,
#                 {
#                     center: [37.5566, 126.9884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_545d6e071d116d711216336e05466516 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_545d6e071d116d711216336e05466516.addTo(map_7b858da06f3dd8a804ba21b8686788fb);
#
#
#
#         function geo_json_342e189745bac12fdb58d50d27e1d164_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_342e189745bac12fdb58d50d27e1d164 = L.geoJson(null, {
#                 onEachFeature: geo_json_342e189745bac12fdb58d50d27e1d164_onEachFeature,
#
#         });
#
#         function geo_json_342e189745bac12fdb58d50d27e1d164_add (data) {
#             geo_json_342e189745bac12fdb58d50d27e1d164
#                 .addData(data);
#         }
#             geo_json_342e189745bac12fdb58d50d27e1d164_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37.49886565522751], [127.1634944215765, 37.497445406097484], [127.16199885180917, 37.49402577547199], [127.16216448592424, 37.491639601211624], [127.16040295326431, 37.4877818619403], [127.15892216655034, 37.486126922469445], [127.15393282790794, 37.48483891408459], [127.15147990997852, 37.47745324805034], [127.1515017465549, 37.475633269417585], [127.14857580353349, 37.47381386382568], [127.14415938171436, 37.47
